# %% [markdown]
# # Lesson: Relational Plots

# %% [markdown]
# ## Demonstration
#
# Statistical analysis involves exploring how variables in a dataset interact and how these interactions are influenced by other variables. Visualization plays a crucial role in this process because it allows the human eye to detect trends and patterns that signify relationships.
#
# The function `relplot()` operates at the figure level and is used to visualize statistical relationships through two main types of plots: scatter plots and line plots.

# %% [markdown]
# ### Scatter Plot (`kind='scatter'`)
# A scatter plot is the default plot type for `relplot()`. It shows the relationship between two numerical variables.

# %%
# Load packages
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

# Load the tips dataset for this tutorial
tips = sns.load_dataset('tips')

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
# Create a scatter plot
sns.relplot(data=tips, x='total_bill', y='tip', kind='scatter',hue = "sex")

# Show the plot
plt.show()

# %% [markdown]
# ### Line Plot (`kind='line'`)
# A line plot is used to show the relationship between two numerical variables, with data points connected by lines. It is useful for visualizing trends over time or ordered categories.
#
# If there are multiple measurements for the same value of the `x` variable, the default behavior in seaborn is to aggregate the multiple measurements at each x value by plotting the mean and the 95% confidence interval around the mean.

# %%
# Create a line plot
sns.relplot(data=tips, x='size', y='total_bill', kind='line')

# Show the plot
plt.show()

# %% [markdown]
# ## Practice
# Now that we've explored how to create relational plots using Seaborn, it's time to put your skills into action! Try the following exercises on your own first, and challenge yourself before checking the provided solutions. But don’t worry, the solutions are available if you need them for guidance

# %% [markdown]
# ### Exercise 1
# Plot a scatter relational plot for `'time'` as `x` and `'total_bill'` as `y`

# %%
# Your Code Here
sns.relplot(data= tips,x = "time",y = "total_bill", kind = "scatter" ,hue = "sex")

# %%
# Create a scatter plot
sns.relplot(data=tips, x='time', y='total_bill')

# Show the plot
plt.show()

# %% [markdown]
# ### Exercise 2
# Plot a line relational plot for `'time'` as `x` and `'total_bill'` as `y`

# %%
# Your Code Here

sns.relplot(data = tips , x = "time" , y = "total_bill",kind = "line")

# %%
# Create a line plot
sns.relplot(data=tips, x='time', y='total_bill', kind='line')

# Show the plot
plt.show()

# %% [markdown]
# ### Exercise 3
# Plot a scatter relational plot for `'day'` as `x` and `'total_bill'` as `y`

# %%
# Your Code Here

sns.relplot(data = tips , x = "day", y = "total_bill",kind = "scatter",hue = "sex")

# %%
# Create a scatter plot
sns.relplot(data=tips, x='day', y='total_bill')

# Show the plot
plt.show()

# %% [markdown]
# ### Exercise 4
# Plot a line relational plot for `'day'` as `x` and `'total_bill'` as `y`

# %%
# Your Code Here

sns.relplot(data = tips , x = "day", y = "total_bill",kind = "line")

# %%
# Create a line plot
sns.relplot(data=tips, x='day', y='total_bill', kind='line')

# Show the plot
plt.show()
