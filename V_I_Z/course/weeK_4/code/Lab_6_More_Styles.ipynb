# %% [markdown]
# # Lesson: More Styles

# %% [markdown]
# ## Demonstration
#
# In Seaborn, the `style` and `size` parameters add more dimensions to your visualizations by differentiating data points with varying marker styles and sizes. This can help make your plots more informative and easier to interpret.

# %% [markdown]
# In the following scatter plot:
# - `hue='smoker'`: Colors the data points based on whether the customer is a smoker.
# - `style='sex'`: Differentiates the data points with different marker styles based on the customer's gender.
# - `size='size'`: Varies the size of the data points based on the party size.

# %%
# Load packages
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

# Load the tips dataset for this tutorial
tips = sns.load_dataset('tips')

# %%
# Create a scatter plot with style and size
sns.relplot(data=tips, x='total_bill', y='tip',
            hue='smoker', style='sex', size='size', kind='scatter')

# Show the plot
plt.show()

# %% [markdown]
# In the following line plot:
# - `hue='sex'`: Colors the lines based on the customer's gender.
# - `style='smoker'`: Differentiates the lines with different styles based on whether the customer is a smoker.
# - `markers=True`: Adds markers to the lines.
# - `dashes=False`: Uses solid lines for all categories.

# %%
# Create a line plot with style
sns.relplot(data=tips, x='size', y='total_bill',
            hue='sex', style='smoker', kind='line')

# Show the plot
plt.show()

# %% [markdown]
# ## Practice
# Now that we've explored how to style plots, it's time to put your skills into action! Try the following exercises on your own first, and challenge yourself before checking the provided solutions. But don’t worry, the solutions are available if you need them for guidance

# %% [markdown]
# ### Exercise 1
# Create a scatter plot to visualize the relationship between `total_bill` and `tip`, using different marker styles based on the `time` of day and varying the marker sizes based on the `day` of the week.

# %%
# Your Code Here

sns.relplot(data = tips , x = "total_bill" , y = "tip" , kind = "scatter", hue = "sex" , style = "time" , size = "day")

# %%
# Create a scatter plot with style and size
sns.relplot(data=tips, x='total_bill', y='tip',
            hue='time', style='time',
            size='day', kind='scatter')

# Show the plot
plt.show()

# %% [markdown]
# ### Exercise 2
# Create a line plot to visualize the relationship between `size` of the party and `total_bill`, using different line styles based on the `smoker` status.

# %%
# Your Code Here

sns.relplot(data = tips , x = "size" , y = "total_bill" , kind = "line" , hue = "smoker",  style = "smoker" )

# %%
# Create a line plot with style
sns.relplot(data=tips, x='size', y='total_bill',
            hue='smoker', style='smoker',
            kind='line', markers=True, dashes=True)

# Show the plot
plt.show()

# %% [markdown]
# ### Exercise 3
# Create a scatter plot to visualize the relationship between `tip` and `size` of the party, using different marker styles based on `sex` and varying the marker sizes based on `total_bill`.

# %%
# Your Code Here
sns.relplot(data=tips, x='tip', y='size', hue='sex', style='sex',size='total_bill', kind='scatter')

# %%
# Create a scatter plot with style and size
sns.relplot(data=tips, x='tip', y='size',
            hue='sex', style='sex',
            size='total_bill', kind='scatter')

# Show the plot
plt.show()
