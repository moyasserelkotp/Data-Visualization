# %% [markdown]
# # Lesson: Adding Colors by 'hue'

# %% [markdown]
# ## Demonstration
#
# The `hue` parameter in Seaborn enhances visualizations by adding a categorical dimension through color differentiation. With `hue`, you can create more informative and visually appealing visualizations that help uncover deeper insights from your data.This tutorial will demonstrate how to use the `hue` parameter with various types of plots in `relplot()`, `displot()`, and `catplot()` functions using the 'tips' dataset. The examples provided demonstrate how to use `hue` with various kinds of plots to enhance your data analysis.

# %% [markdown]
# Using `hue` with `relplot()`: The `relplot()` function can create scatter plots and line plots. In the following scatter plot, data points are colored based on the customer's gender, allowing comparison of the relationship between total bill and tip amounts for males and females.

# %%
# Load packages
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

# Load the tips dataset for this tutorial
tips = sns.load_dataset('tips')

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
# Create a scatter plot with hue
sns.relplot(data=tips, x='total_bill', y='tip', hue='sex', kind='scatter')

# Show the plot
plt.show()

# %% [markdown]
# In the following line plot, the lines are colored based on the customer's gender, showing the trend of total bill amounts with party size for males and females.

# %%
# Create a line plot with hue
sns.relplot(data=tips, x='size', y='total_bill', hue='sex', kind='line')

# Show the plot
plt.show()

# %% [markdown]
# Using `hue` with `displot()`: The `displot()` function can create histograms, KDE plots, and ECDF plots. In the following histogram, bars are colored based on the customer's gender, providing a comparison of tip amount distributions between males and females.

# %%
# Create a histogram with hue
sns.displot(data=tips, x='tip', hue='sex', kind='hist')

# Show the plot
plt.show()

# %%
# Create a histogram with hue and stacking
sns.displot(data=tips, x='tip', hue='sex', kind='hist', multiple='stack')

# Show the plot
plt.show()

# %% [markdown]
# In the following KDE plot, the distributions of tip amounts are colored based on whether the customer is a smoker, allowing for comparison of tip distributions between smokers and non-smokers.

# %%
# Create a KDE plot with hue
sns.displot(data=tips, x='tip', hue='smoker', kind='kde')

# Show the plot
plt.show()

# %%
# Create a KDE plot with hue and stacking
sns.displot(data=tips, x='tip', hue='smoker', kind='kde', multiple='stack')

# Show the plot
plt.show()

# %% [markdown]
# In the following ECDF plot, lines are colored based on the day of the week, providing a cumulative view of total bill distributions across different days.

# %%
# Create an ECDF plot with hue
sns.displot(data=tips, x='total_bill', hue='day', kind='ecdf')

# Show the plot
plt.show()

# %% [markdown]
# The `catplot()` function can create strip plots, swarm plots, box plots, violin plots, bar plots, and point plots. In the following strip plot, data points are colored based on whether the customer is a smoker, showing the distribution of total bill amounts across different days.

# %%
# Create a strip plot with hue
sns.catplot(data=tips, x='day', y='total_bill', hue='smoker', kind='strip')

# Show the plot
plt.show()

# %% [markdown]
# In the following swarm plot, data points are colored based on the customer's gender, visualizing the distribution of tips across different days.

# %%
# Create a swarm plot with hue
sns.catplot(data=tips, x='day', y='tip', hue='sex', kind='swarm')

# Show the plot
plt.show()

# %% [markdown]
# In the following box plot, boxes are colored based on the customer's gender, comparing the distribution of total bill amounts for lunch and dinner between males and females.

# %%
# Create a box plot with hue
sns.catplot(data=tips, x='time', y='total_bill', hue='sex', kind='box')

# Show the plot
plt.show()

# %% [markdown]
# In the following violin plot, distributions are colored based on the customer's gender, showing the density of tips for lunch and dinner between males and females.

# %%
# Create a violin plot with hue
sns.catplot(data=tips, x='time', y='tip', hue='sex', kind='violin')

# Show the plot
plt.show()

# %%
# Create a violin plot with hue and make the split as True
sns.catplot(data=tips, x='time', y='tip',
            hue='sex', kind='violin', split=True)

# Show the plot
plt.show()

# %% [markdown]
# In the following bar plot, bars are colored based on the customer's gender, comparing the average total bill amounts across different days between males and females.

# %%
# Create a bar plot with hue
sns.catplot(data=tips, x='day', y='total_bill', hue='sex', kind='bar')

# Show the plot
plt.show()

# %% [markdown]
# In the following point plot, points and lines are colored based on whether the customer is a smoker, visualizing the average tip amounts across different days for smokers and non-smokers.

# %%
# Create a point plot with hue
sns.catplot(data=tips, x='day', y='tip', hue='smoker', kind='point')

# Show the plot
plt.show()

# %% [markdown]
# ## Practice
# Now that we've explored how to use the `hue` parameter in Seaborn plots, it's time to put your skills into action! Try the following exercises on your own first, and challenge yourself before checking the provided solutions. But don’t worry, the solutions are available if you need them for guidance

# %% [markdown]
# ### Exercise 1
# Create a scatter plot to visualize the relationship between 'total_bill' and 'tip', with points colored based on the 'day' attribute.

# %%
# Your Code Here
sns.relplot(data=tips , x= "total_bill" , y = "tip" ,kind = "scatter",hue = "day")

# %%
# Create a scatter plot with hue based on day
sns.relplot(data=tips, x='total_bill', y='tip', hue='day', kind='scatter')

# Show the plot
plt.show()

# %% [markdown]
# ### Exercise 2
# Create a KDE plot to visualize the the distribution of 'total_bill', with lines colored based on the 'time' attribute.

# %%
# Your Code Here

sns.displot(data = tips , x="total_bill" , kind = "kde" , hue = "time")

# %%
# Create a KDE plot with hue based on time
sns.displot(data=tips, x='total_bill', hue='time', kind='kde')

# Show the plot
plt.show()

# %% [markdown]
# ### Exercise 3
# Create an ECDF plot to visualize the cumulative distribution of 'tip', with lines colored based on the 'sex' attribute.

# %%
# Your Code Here

sns.displot(data = tips , x="tip" , kind = "ecdf" , hue = "sex")

# %%
# Create an ECDF plot with hue based on sex
sns.displot(data=tips, x='tip', hue='sex', kind='ecdf')

# Show the plot
plt.show()

# %% [markdown]
# ### Exercise 4
# Create a violin plot to visualize the distribution of 'total_bill', with sections colored based on the 'smoker' attribute.

# %%
# Your Code Here
sns.catplot(data = tips , x= "time", y = "total_bill" , kind = "violin" , hue = "smoker",split = True)

# %%
# Create a violin plot with hue based on smoker status
sns.catplot(data=tips, x='day', y='total_bill',
            hue='smoker', kind='violin')

# Show the plot
plt.show()

# %% [markdown]
# ### Exercise 5
# Create a bar plot to visualize the average 'tip' amounts for each day, with bars colored based on the 'time' attribute.

# %%
# Your Code Here
sns.catplot(data = tips , x= "day", y = "tip" , kind = "bar" , hue = "smoker")

# %%
# Create a bar plot with hue based on time
sns.catplot(data=tips, x='day', y='tip', hue='time', kind='bar')

# Show the plot
plt.show()

# %% [markdown]
# ### Exercise 6
# Create a point plot to visualize the average 'total_bill' amounts for each party size, with points colored based on the 'smoker' attribute.

# %%
# Your Code Here
sns.catplot(data = tips , x= "size", y = "total_bill" , kind = "point" , hue = "smoker")

# %%
# Create a point plot with hue based on smoker status
sns.catplot(data=tips, x='size', y='total_bill',
            hue='smoker', kind='point')

# Show the plot
plt.show()
