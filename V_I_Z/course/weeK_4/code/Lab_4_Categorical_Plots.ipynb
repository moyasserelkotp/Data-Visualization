# %% [markdown]
# # Lesson: Categorical Plots

# %% [markdown]
# ## Demonstration
#
# The `catplot()` function in Seaborn visualizes the relationship between categorical data and other variables. By using the `kind` parameter, you can create strip plots, swarm plots, box plots, violin plots, bar plots, and point plots to explore the relationship between categorical variables and other data in your dataset. The 'tips' dataset provides an excellent starting point for practicing these techniques.

# %% [markdown]
# ### Strip Plot (`kind='strip'`)
# A strip plot shows individual data points along an axis, which can be useful for visualizing the distribution of data points within categories. The following strip plot displays the distribution of total bill amounts for each day of the week.

# %%
# Load packages
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

# Load the tips dataset for this tutorial
tips = sns.load_dataset('tips')

# %%
# Create a strip plot
sns.catplot(data=tips, x='day', y='total_bill', kind='strip')

# Show the plot
plt.show()

# %% [markdown]
# ### Swarm Plot (`kind='swarm'`)
# A swarm plot is similar to a strip plot but adjusts the positions of the data points to prevent them from overlapping, providing a clearer view of the distribution. The following swarm plot shows the distribution of total bill amounts for each day of the week without overlapping points.

# %%
# Create a swarm plot
sns.catplot(data=tips, x='day', y='total_bill', kind='swarm')

# Show the plot
plt.show()

# %% [markdown]
# ### Box Plot (`kind='box'`)
# A box plot shows the distribution of data based on a five-number summary: minimum, first quartile (Q1), median, third quartile (Q3), and maximum. It also highlights outliers. The following box plot visualizes the distribution of total bill amounts for each day of the week.

# %%
# Create a box plot
sns.catplot(data=tips, x='day', y='total_bill', kind='box')

# Show the plot
plt.show()

# %% [markdown]
# ### Violin Plot (`kind='violin'`)
# A violin plot combines aspects of a box plot and a KDE plot, showing the distribution of the data across different categories. The following violin plot displays the distribution of total bill amounts for each day of the week, including the density of the data.

# %%
# Create a violin plot
sns.catplot(data=tips, x='day', y='total_bill', kind='violin')

# Show the plot
plt.show()

# %% [markdown]
# ### Bar Plot (`kind='bar'`)
# A bar plot shows the central tendency of the data for each category along with error bars to indicate variability. The following bar plot displays the average total bill amounts for each day of the week, with error bars indicating the standard error.

# %%
# Create a bar plot
sns.catplot(data=tips, x='day', y='total_bill', kind='bar')

# Show the plot
plt.show()

# %% [markdown]
# ### Point Plot (`kind='point'`)
# A point plot is similar to a bar plot but uses points and lines to show the central tendency and variability of the data for each category. The following point plot visualizes the average total bill amounts for each day of the week, with lines indicating the standard error.

# %%
# Create a point plot
sns.catplot(data=tips, x='day', y='total_bill', kind='point')

# Show the plot
plt.show()

# %% [markdown]
# ## Practice
# Now that we've explored how to create categorical plots, it's time to put your skills into action! These problems will use different attributes of the Seaborn 'tips' dataset to create various types of plots. Try the following exercises on your own first, and challenge yourself before checking the provided solutions. But don’t worry, the solutions are available if you need them for guidance.

# %% [markdown]
# ### Exercise 1
# Create a strip plot showing the distribution of the 'tip' column for different times of day ('time').

# %%
# Your Code Here

sns.catplot(data = tips ,x = "time", y = "tip",kind = "strip")

# %%
# Create a strip plot of tips by time of day
sns.catplot(data=tips, x='time', y='tip', kind='strip')

# Show the plot
plt.show()

# %% [markdown]
# ### Exercise 2
# Create a swarm plot showing the distribution of the 'total_bill' column for different sexes ('sex')

# %%
# Your Code Here

sns.catplot(data = tips , x = "sex", y = "total_bill",kind = "swarm")

# %%
# Create a swarm plot of total bill by sex
sns.catplot(data=tips, x='sex', y='total_bill', kind='swarm')

# Show the plot
plt.show()

# %% [markdown]
# ### Exercise 3
# Calculate the tip percentage for each entry in the dataset and create a box plot to visualize the distribution of tip percentages for different days of the week ('day')

# %%
# Your Code Here

sns.catplot(data = tips , x = "day", y = "tip",kind = "box")

# %%
# Calculate tip percentage
tips['tip_percentage'] = tips['tip'] / tips['total_bill'] * 100

# Create a box plot of tip percentages by day
sns.catplot(data=tips, x='day', y='tip_percentage', kind='box')

# Show the plot
plt.show()

# %% [markdown]
# ### Exercise 4
# Create a violin plot to visualize the distribution of the 'total_bill' column for smokers and non-smokers ('smoker').

# %%
# Your Code Here

sns.catplot(data = tips , x = "smoker", y = "total_bill",kind = "violin")

# %%
# Create a violin plot of total bill by smoker status
sns.catplot(data=tips, x='smoker', y='total_bill', kind='violin')

# Show the plot
plt.show()

# %% [markdown]
# ### Exercise 5
# Create a bar plot to visualize the average 'tip' amounts for different sexes ('sex'), with error bars indicating the standard error.

# %%
# Your Code Here

sns.catplot(data = tips , x = "sex", y = "tip",kind = "bar")

# %%
# Create a bar plot of average tips by sex
sns.catplot(data=tips, x='sex', y='tip', kind='bar')

# Show the plot
plt.show()

# %% [markdown]
# ### Exercise 6
# Create a point plot to visualize the average 'tip' amounts for different days of the week ('day'), with lines indicating the standard error.

# %%
# Your Code Here

sns.catplot(data = tips , x = "day", y= "tip", kind = "point")

# %%
# Create a point plot of average tip by day
sns.catplot(data=tips, x='day', y='tip', kind='point')

# Show the plot
plt.show()

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4
