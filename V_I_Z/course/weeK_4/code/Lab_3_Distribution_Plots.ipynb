# %% [markdown]
# # Lesson: Distribution Plots

# %% [markdown]
# ## Demonstration
#
# The `displot()` function in Seaborn is a versatile tool for visualizing the distribution of a dataset.
#
# ### Histogram (`kind='hist'`)
# A histogram displays the distribution of a dataset by dividing the data into bins and counting the number of observations in each bin. The following histogram shows the distribution of the total bill amounts in the 'tips' dataset.

# %%
# load packages
import pandas as pd 
import numpy as np 

import matplotlib.pyplot as plt
import seaborn as sns

# Load the tips dataset for this tutorial
tips = sns.load_dataset('tips')

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
# Create a histogram with 100 bins
sns.displot(tips, x='total_bill', kind='hist', bins = 100)

# Show the plot
plt.show()

# %% [markdown]
# ### Kernel Density Estimate Plot (`kind='kde'`)
# A Kernel Density Estimate (KDE) plot is a smoothed version of the histogram, which estimates the probability density function of the data. The following KDE plot shows the smoothed distribution of the total bill amounts in the 'tips' dataset.

# %%
# Create a KDE plot
sns.displot(tips, x='total_bill', kind='kde')

# Show the plot
plt.show()

# %% [markdown]
# ### Empirical Cumulative Distribution Function Plot (`kind='ecdf'`)
# An ECDF plot shows the proportion of observations less than or equal to a particular value, providing a cumulative view of the data distribution. The following ECDF plot displays the cumulative distribution of the total bill amounts in the 'tips' dataset.

# %%
# Create an ECDF plot
sns.displot(tips, x='total_bill', kind='ecdf')

# Show the plot
plt.show()

# %% [markdown]
# ## Practice
#
# Now that we've explored how to create distribution plots, it's time to put your skills into action! These problems will use different attributes of the Seaborn 'tips' dataset to create various types of distribution plots. Try the following exercises on your own first, and challenge yourself before checking the provided solutions. But don’t worry, the solutions are available if you need them for guidance

# %% [markdown]
# ### Exercise 1
# Create a histogram to visualize the distribution of tip amounts in the 'tips' dataset.

# %%
# Your Code Here

sns.displot(tips, x = "tip", kind = "hist",bins = 10)

# %%
# Create a histogram of tip amounts
sns.displot(tips, x='tip', kind='hist')

# Show the plot
plt.show()

# %% [markdown]
# ### Exercise 2
# Create a KDE plot to visualize the distribution of tip amounts.

# %%
# Your Code Here

sns.displot(tips , x = "tip" , kind = "kde" )

# %%
# Create a KDE plot of tips
sns.displot(tips, x='tip', kind='kde')

# Show the plot
plt.show()

# %% [markdown]
# ### Exercise 3
# Create an ECDF plot to visualize tip amounts.

# %%
# Your Code Here

sns.displot(tips , x = "tip" , kind = "ecdf")

# %%
# Create an ECDF plot of tip percentages
sns.displot(tips, x='tip', kind='ecdf')

# Show the plot
plt.show()

# %% [markdown]
# ### Exercise 4
# Create a histogram to visualize the distribution of the size of dining parties.

# %%
# Your Code Here
sns. displot(tips , x = "size" , kind = "hist",bins = 6)

# %%
tips["size"].value_counts()
# Out:
# 2    156
# 3     38
# 4     37
# 5      5
# 1      4
# 6      4
# Name: size, dtype: int64

# %%
# Create a histogram of the size of dining parties
sns.displot(tips, x='size', kind='hist')

# Show the plot
plt.show()

# %% [markdown]
# ### Exercise 5
# Create a KDE plot to visualize the distribution of size.

# %%
# Your Code Here

sns.displot(tips , x = "size" , kind = "kde")

# %%
# Create a KDE plot of size
sns.displot(tips, x='size', kind='kde')

# Show the plot
plt.show()

# %% [markdown]
# ### Exercise 6
# Create a ECDF plot to visualize the distribution of size.

# %%
# Your Code Here

sns.displot(tips , x = "size" ,kind = "ecdf")

# %%
# Create a ECDF plot of size
sns.displot(tips, x='size', kind='ecdf')

# Show the plot
plt.show()
