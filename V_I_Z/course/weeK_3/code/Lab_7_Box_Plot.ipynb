# %% [markdown]
# # Part 6: Box Plot
# This case study will walk you through how to visualize economic data using various Matplotlib plots. We will use the dataset provided, which contains the following columns:
#
# - Year
# - GDP
# - GDP_PerCapita
# - GDP_Growth
# - Inflation
# - Unemployment
# - Inflation_Change
#
# In this sixth part, we'll use Matplotlib to create box plots to visualize the spred of GDP growth rates, inflation rates, and unemployment rates. To begin, import the libraries and data in the cell below. Then, complete the following exercises.

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

df = pd.read_csv('EcoOfUs.csv')
df.info()

# %% [markdown]
# ### Exercise 1
# Create a box plot to visualize the spread of GDP growth rates.

# %%
# Your Code Here

# %%
plt.boxplot(df['GDP_Growth'])
plt.title('GDP Growth Rate Spread')
plt.ylabel('GDP Growth Rate (%)')
plt.show()

# %% [markdown]
# ### Exercise 2
# Create a box plot to visualize the spread of Inflation Rates.

# %%
# Your Code Here

# %%
plt.boxplot(df['Inflation'])
plt.title('Inflation Rate Spread')
plt.ylabel('Inflation Rate (%)')
plt.show()

# %% [markdown]
# ### Exercise 3
# Create a box plot to visualize the spread of Unemployment Rates.

# %%
# Your Code Here

# %%
plt.boxplot(df['Unemployment'])
plt.title('Unemployment Rate Spread')
plt.ylabel('Unemployment Rate (%)')
plt.show()
