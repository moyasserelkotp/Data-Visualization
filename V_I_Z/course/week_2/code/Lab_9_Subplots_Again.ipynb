# %% [markdown]
# # Lesson: Revisitng Subplots
# Welcome to the lab on revisiting subplots! We have learned how subplots enable us to put multiple plots together. Let's revisit this concept and organize various types of plots together to make a dashboard.

# %% [markdown]
# ## Demonstration
#
# Subplots are useful for organizing multiple plots in a single figure. They allow you to compare different visualizations side by side.
#
# ### Syntax
# The basic syntax for creating subplots in Matplotlib is:
# ```python
# fig, axs = plt.subplots(nrows, ncols, options)
# ```
# where:
#
# - `nrows` and `ncols` specify the number of rows and columns of subplots.
# - `options` include figure size, spacing, and other styling options.
#
# If you would like to learn more about creating subplots with Matplotlib and the full list of customization options, you can visit the [Matplotlib Subplots Documentation](https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.subplots.html).

# %%
import matplotlib.pyplot as plt
import numpy as np

# Make two dummy datasets
x = sorted(np.random.rand(100))
y = x + np.random.rand(100)
z = x + np.random.randn(100)

# Creating subplots
fig, axs = plt.subplots(3, 3)
axs[0,0].hist(x, bins=10)
axs[0,0].set_title('x')

axs[0,1].scatter(x, y)
axs[0,1].set_title('x vs y')

axs[0,2].scatter(x, z)
axs[0,2].set_title('x vs z')

axs[1,0].scatter(y, x)
axs[1,0].set_title('y vz x')

axs[1,1].hist(y, bins=10)
axs[1,1].set_title('y')

axs[1,2].scatter(y, z)
axs[1,2].set_title('y vs z')

axs[2,0].scatter(z, x)
axs[2,0].set_title('z vs x')

axs[2,1].scatter(z, y)
axs[2,1].set_title('z vs y')

axs[2,2].hist(z, bins=10)
axs[2,2].set_title('z')

# Display the plots
plt.tight_layout(pad=0.4, w_pad=0.5, h_pad=1.0)
plt.show()

# %% [markdown]
# ## Practice
# Now that we've explored how to mix plots using subplots, it's time to put your skills into action! Try the following exercises on your own first, and challenge yourself before checking the provided solutions. But don’t worry, the solutions are available if you need them for guidance

# %% [markdown]
# ### Exercise 1
# Create multiple line plots in a single figure with x values `[1, 2, 3, 4, 5]` and two sets of y values `[2, 3, 5, 4, -1]` and `[4, 2, 8, 9, 5]`.

# %%
# Your Code Here

x = [1, 2, 3, 4, 5]
     
y1 = [2, 3, 5, 4, -1]
y2 = [4, 2, 8, 9, 5]
     
plt.plot(x,y1, color = "r",label = "Y1",marker = "o")     
plt.plot(x,y2, color = "b",label = "Y2",marker = "o")     

plt.title("X & Y1 & Y2")
plt.legend()

plt.show()

# %%
x = [1, 2, 3, 4, 5]
y1 = [2, 3, 5, 4, -1]
y2 = [4, 2, 8, 9, 5]

plt.plot(x, y1, label='y1')
plt.plot(x, y2, label='y2')
plt.title('Multiple Line Plots')
plt.xlabel('X values')
plt.ylabel('Y values')
plt.legend()categories = ['A', 'B', 'C', 'D']
plt.show()

# %% [markdown]
# ### Exercise 2
# Create multiple line plots in a single figure with x values `[1, 2, 3, 4, 5]` and two sets of y values `[2, 3, 5, 4, -1]`, label as `year2020`, and `[4, 2, 8, 9, 5]`, label as `year2024`, with the category as `['Agent1', 'Agent2', 'Agent3', 'Agent4', 'Agent5']`. Create a 2 by 2 multiplots that has:
#
#
# 1.   A line plot of x values as x, y1 and y2 values as y in the same plot.
# 1.   A scatter plot of y1 and y2.
# 1.   A bar plot of y1 and category.
# 1.   A bar plot of y2 and category.

# %%
# Your Code Here

x =  [1, 2, 3, 4, 5]
y1 = [2, 3, 5, 4, -1]
y2 = [4, 2, 8, 9, 5]
category = ['Agent1', 'Agent2', 'Agent3', 'Agent4', 'Agent5']

plt.figure(figsize=(10,6))

plt.subplot(2,2,1)
plt.plot(x, y1, label='year2020')
plt.plot(x, y2, label='year2024')
plt.legend()

plt.subplot(2,2,2)
plt.scatter(y1, y2)

plt.subplot(2,2,3)
plt.bar(category, y1, color='blue')

plt.subplot(2,2,4)
plt.bar(category, y2, color='Green')

plt.show()

# %%
x = [1, 2, 3, 4, 5]
y1 = [2, 3, 5, 4, -1]
y2 = [4, 2, 8, 9, 5]
category = ['Agent1', 'Agent2', 'Agent3', 'Agent4', 'Agent5']

fig, axs = plt.subplots(2, 2)

axs[0, 0].plot(x, y1, label='year2020')
axs[0, 0].plot(x, y2, label='year2024')
axs[0, 0].set_title('Yearly Comparison')
axs[0, 0].legend()

axs[0, 1].scatter(y1, y2)
axs[0, 1].set_title('Agent Comparison')

axs[1, 0].bar(category, y1, color='blue')
axs[1, 0].set_title('Year 2020 Agents')

axs[1, 1].bar(category, y2, color='Green')
axs[1, 1].set_title('Year 2024 Agents')

plt.tight_layout(pad=0.4, w_pad=0.5, h_pad=1.0)
plt.show()
