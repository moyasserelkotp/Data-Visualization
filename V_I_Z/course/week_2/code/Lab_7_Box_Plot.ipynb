# %% [markdown]
# # Lesson: Box Plot
# Welcome to the lab on box plots! A box plot (or whisker plot) provides a summary of a dataset’s distribution, highlighting the median, quartiles, and potential outliers. It is especially useful for comparing multiple datasets. Let's begin!

# %% [markdown]
# ## Demonstration
#
# Box plots are useful for visualizing the distribution of a dataset through its quartiles. They provide a clear summary of the data's central tendency, variability, and potential outliers.
#
# ### Syntax:
# ```python
# plt.boxplot(data, options)
# ```
# where:
# - `data` is the data to be visualized.
# - `options` include styling optionsfor orientation, filled boxes, and showing statistics.
#
# The following box plot visualizes the spread and skewness of the dataset. It highlights the median, quartiles, and potential outliers.
#
# If you would like to learn more about creating box plots with Matplotlib, you can visit the [Matplotlib Box Plot Documentation](https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.boxplot.html).

# %%
import matplotlib.pyplot as plt

# Dummy data
data = [1, 2, 2, 3, 4, 6, 6, 7, 8, 9, 10]

# Creating the box plot
plt.boxplot(data)

# Adding title and labels
plt.title('Box Plot of Data')
plt.xlabel('Data')
plt.ylabel('Value')

# Show plot
plt.show()

# %% [markdown]
# ## Practice
# Now that we've explored how to create a box plot, it's time to put your skills into action! Try the following exercises on your own first, and challenge yourself before checking the provided solutions. But don’t worry, the solutions are available if you need them for guidance

# %% [markdown]
# ### Exercise 1
# Create a box plot for the 100 random floats within `[0, 1]`

# %%
# Your Code Here
import numpy as np 

x = np.random.rand(100)

plt.boxplot(x)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x725b1abd8910>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x725b1abd8e50>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x725b1abd8670>],
#  'medians': [<matplotlib.lines.Line2D at 0x725b1abd9390>],
#  'fliers': [<matplotlib.lines.Line2D at 0x725b1abd9630>],
#  'means': []}

# %%
data = np.random.rand(100)

plt.boxplot(data)
plt.title('Box Plot')
plt.ylabel('Values')
plt.show()
